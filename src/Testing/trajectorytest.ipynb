# %%
import sys
import os
import numpy as np
sys.path.insert(1, "/Users/alistair/Projects/Dissertation/Jenson/src")
from  Models.track import Track
from Models.robot import Robot
from Utils.state import State
from Utils.action import Action
from Utils.trajectory import Trajectory
import config

car = Robot()

action = Action(0, 1, car)
action2 = Action(0, 0, car)
state = State(0,0, -np.pi/2, 1 )
actions = [action for i in range(0, 5)] + [action2 for i in range(0, 15)]


states = [state]

for action in actions:
    new_state = action.apply(state)
    states.append(new_state)
    print(state.v)
    state = new_state

traj = Trajectory(states[:-1], actions)

# save trajectory to trajectories folder
path = os.path.join(config.SRC_PATH, "Trajectories")
traj.write_to_json(path + "/linear_traj.json")
# Out:
# 1
# 1.1
# 1.2000000000000002
# 1.3000000000000003
# 1.4000000000000004
# 1.5000000000000004
# 1.5000000000000004
# 1.5000000000000004
# 1.5000000000000004
# 1.5000000000000004
# 1.5000000000000004
# 1.5000000000000004
# 1.5000000000000004
# 1.5000000000000004
# 1.5000000000000004
# 1.5000000000000004
# 1.5000000000000004
# 1.5000000000000004
# 1.5000000000000004
# 1.5000000000000004

# %%
traj.plot_states()

# %%
traj.plot_actions()
